# %%
import json

# %%
gen_data = None
with open("../../Apps/CloudConvert/genocide_data.tar/genocide_data/genocide_clusters_20151005_251115_11_22.json") as j:
    gen_data = json.load(j)

# %%
type(gen_data)
# Out:
# list

# %%
for gd in gen_data:
    print(gd.keys())
# Out:
# dict_keys(['cnoprefix', 'user_entropy', 'cstr', 'twids', 'rif', 'ctweettuplelist', 'cno', '_id'])
# dict_keys(['cnoprefix', 'user_entropy', 'cstr', 'twids', 'rif', 'ctweettuplelist', 'cno', '_id'])
# dict_keys(['cnoprefix', 'user_entropy', 'cstr', 'twids', 'rif', 'ctweettuplelist', 'cno', '_id'])
# dict_keys(['cnoprefix', 'user_entropy', 'cstr', 'twids', 'rif', 'ctweettuplelist', 'cno', '_id'])
# dict_keys(['cnoprefix', 'user_entropy', 'cstr', 'twids', 'rif', 'ctweettuplelist', 'cno', '_id'])
# dict_keys(['cnoprefix', 'user_entropy', 'cstr', 'twids', 'rif', 'ctweettuplelist', 'cno', '_id'])
# dict_keys(['cnoprefix', 'user_entropy', 'cstr', 'twids', 'rif', 'ctweettuplelist', 'cno', '_id'])
# dict_keys(['cnoprefix', 'user_entropy', 'cstr', 'twids', 'rif', 'ctweettuplelist', 'cno', '_id'])
# dict_keys(['cnoprefix', 'user_entropy', 'cstr', 'twids', 'rif', 'ctweettuplelist', 'cno', '_id'])
# dict_keys(['cnoprefix', 'user_entropy', 'cstr', 'twids', 'rif', 'ctweettuplelist', 'cno', '_id'])
# ...

# %%
gen_data2 = None
with open("../../Apps/CloudConvert/genocide_data.tar/genocide_data/genocide_clusters_20151005_301115_22_40.json") as j:
    gen_data2 = json.load(j)

# %%
for gd in gen_data2:
    if "label" in gd.keys():
        print(gd["label"])
        for twt in gd["ctweettuplelist"][:2]:
            print(twt[2])
        print()
        for twt in gd["ctweettuplelist"][-2:]:
            print(twt[2])
        print("***************************************************")
# Out:
# actualcases
# rohingya refugees: stateless in southaest asia - photographs by saiful huq omi urlurlurl
# stunning, committed work by saiful huq omi photographing the stateless rohingya urlurlurl urlurlurl
#
# saiful huq is the man urlurlurl
# great work, saiful huq omi!
#
# “burma is becoming the next big place for the world’s capital.  but if you are from... urlurlurl
# ***************************************************
# irrelevant
# i'm screaming😂💀💀💀 urlurlurl
# genocide of the donaldsonvillians tonight. 💀
#
# the fact that you took my tweet serious 💀 urlurlurl
# diddy, we are committing genocide on ourselves: the mogul complained about the #blacklivesmatter movement, saying "… urlurlurl
# ***************************************************
# incoherent
# brettgarrot: brettgarrot: brettgarrot: brettgarrot: brettgarrot: brettgarrot: brettgarrot: modrizwan: how #un can ignore the #genocide of p…
# ...

# %%
len([g for g in gen_data2 if "label" in g.keys()])
# Out:
# 34

# %%
type(gen_data2[0]["user_entropy"])
# Out:
# float
